# %% [markdown]
# # Criação

# %%
tupla = tuple()
print(tupla)

tupla = (1,2,3,4,5,6) # Carrega vários valores, nao apenas um só
letras = ('a','b','c') # Carrega vários valores, nao apenas um só
tupla
# Out:
# ()
# (1, 2, 3, 4, 5, 6)

# %%
a = 10
b=15
tup_a = (a,b) # Tupla não conecta com o valor de fora (Há exceção para lista)
a=5
tup_a
# Out:
# (10, 15)

# %% [markdown]
# # Slices

# %%
tupla[::-1]
tupla[3:]
tupla[3]
# Out:
# 4

# %%
type((5,))
# Out:
# tuple

# %%
(5,) + (5,6)
# Out:
# (5, 5, 6)

# %% [markdown]
# # Operações

# %%
tup_b = (10,20,30)
tup_a+tup_b
# Out:
# (10, 15, 10, 20, 30)

# %%
tup_a*3
# Out:
# (10, 15, 10, 15, 10, 15)

# %% [markdown]
# ## Funções

# %%
len(tup_a)
# Out:
# 2

# %%
tup_b.count(20)
# Out:
# 1

# %%
print(tup_b)
tup_b.index(30)
# Out:
# (10, 20, 30)
# 2

# %%
novo_valor = (15,16,17)
tup_j = (10,11,16,19,20) # Mudar 16 para 15
# tup_j[1] = 15 Erro, não é editavel

tup_j = tup_j[0:2] + novo_valor + tup_j[3:]
# Out:
# (10, 11, 15, 16, 17, 19, 20)

# %%
jogador_1 = {
    'hp':20,
    'mana':50,
    'classe':'Mago'
} #Dicionario

# %%
jogador_1 = (20,50,'Mago')
jogador_1[0]
# Out:
# 20
